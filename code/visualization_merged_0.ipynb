# %%
import pandas as pd
import numpy as np

# %%
icu_df = pd.read_csv("../data/ICUSTAYS.csv")
icu_df.head(10)
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID DBSOURCE FIRST_CAREUNIT  \
# 0     365         268   110404      280836  carevue           MICU
# 1     366         269   106296      206613  carevue           MICU
# 2     367         270   188028      220345  carevue            CCU
# 3     368         271   173727      249196  carevue           MICU
# 4     369         272   164716      210407  carevue            CCU
# 5     370         273   158689      241507  carevue           MICU
# 6     371         274   130546      254851  carevue           MICU
# 7     372         275   129886      219649  carevue            CCU
# 8     373         276   135156      206327  carevue            CCU
# 9     374         277   171601      272866  carevue           NICU
#
#   LAST_CAREUNIT  FIRST_WARDID  LAST_WARDID            INTIME  \
# 0          MICU            52           52   2198/2/14 23:27
# 1          MICU            52           52   2170/11/5 11:05
# ...

# %%
icu_df['']

# %%
icu_df.nlargest(10, 'LOS')
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID DBSOURCE FIRST_CAREUNIT  \
# 17024   16052       12613   168201      245503  carevue          TSICU
# 21734   19275       15204   168396      257713  carevue           NICU
# 35878   37865       29899   169327      224633  carevue           NICU
# 19797   20573       16244   114862      267553  carevue           NICU
# 17662   15228       11923   194773      275498  carevue           CSRU
# 9910     8864        6975   192431      211378  carevue           NICU
# 4216     3789        3014   126258      236391  carevue           NICU
# 20919   25900       20415   117600      215945  carevue           NICU
# 16675   16014       12578   172706      245841  carevue           NICU
# 571      1106         862   186550      281026  carevue           NICU
#
#       LAST_CAREUNIT  FIRST_WARDID  LAST_WARDID               INTIME  \
# 17024          SICU            23           33  2136-04-27 11:43:31
# ...

# %%
patient_df = pd.read_csv("../data/PATIENTS.csv")
patient_df.head(5)
# Out:
#    ROW_ID  SUBJECT_ID GENDER                  DOB                  DOD  \
# 0     234         249      F  2075-03-13 00:00:00                  NaN
# 1     235         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 2     236         251      M  2090-03-15 00:00:00                  NaN
# 3     237         252      M  2078-03-06 00:00:00                  NaN
# 4     238         253      F  2089-11-26 00:00:00                  NaN
#
#               DOD_HOSP DOD_SSN  EXPIRE_FLAG
# 0                  NaN     NaN            0
# 1  2188-11-22 00:00:00     NaN            1
# 2                  NaN     NaN            0
# 3                  NaN     NaN            0
# 4                  NaN     NaN            0

# %%
patient_df[patient_df['SUBJECT_ID']==12613]
# Out:
#        ROW_ID  SUBJECT_ID GENDER                  DOB                  DOD  \
# 13038   11933       12613      M  2075-09-03 00:00:00  2137-08-21 00:00:00
#
#       DOD_HOSP              DOD_SSN  EXPIRE_FLAG
# 13038      NaN  2137-08-21 00:00:00            1

# %%
diag_df = pd.read_csv("../data/DIAGNOSES_ICD.csv")
diag_df.head(5)
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0    1297         109   172335      1.0     40301
# 1    1298         109   172335      2.0       486
# 2    1299         109   172335      3.0     58281
# 3    1300         109   172335      4.0      5855
# 4    1301         109   172335      5.0      4254

# %%
diag_df[diag_df['ICD9_CODE'] == '40301']
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0         1297         109   172335      1.0     40301
# 14        1311         109   173633      1.0     40301
# 1130      1019         109   131345      1.0     40301
# 1150      1039         109   131376      1.0     40301
# 1170      1059         109   135923      1.0     40301
# 1187      1076         109   136572      3.0     40301
# 1201      1090         109   137510      1.0     40301
# 1221      1110         109   139061      1.0     40301
# 1234      1123         109   140167      1.0     40301
# 1251      1140         109   147469      1.0     40301
# 1268      1157         109   151240      1.0     40301
# 1288      1177         109   155726      1.0     40301
# 1315      1204         109   158943      3.0     40301
# 1342      1231         109   158995      3.0     40301
# 1360      1249         109   161950      1.0     40301
# 1373      1262         109   164029      1.0     40301
# ...

# %%
disease_df = pd.read_csv("../data/D_ICD_DIAGNOSES.csv")
disease_df[disease_df['ICD9_CODE'] == '40301']
# Out:
#       ROW_ID ICD9_CODE             SHORT_TITLE  \
# 4311    4312     40301  Mal hyp kid w cr kid V
#
#                                              LONG_TITLE
# 4311  Hypertensive chronic kidney disease, malignant...

# %%
print('hello, world')
# Out:
# hello, world
