# %% [markdown]
# ## Code for Linear Regression and Decision Tree

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from datetime import timezone, datetime
from sklearn.preprocessing import OneHotEncoder 
from sklearn.preprocessing import LabelEncoder
#from sklearn.compose import ColumnTransformer 
import datetime as dt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold 
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ### Importing Dataset
# hingek10.csv and hingek20.csv are the training results of the low rank model of clustering the patients' information. Diabetes_Numerical.csv is the dataset used for training linear regression and decision tree models.

# %%
hinge10 = pd.read_csv('../data/hingek10.csv')
hinge20 = pd.read_csv('../data/hingek20.csv')
origin20 = pd.read_csv('../data/GLRMk20.csv')
origin5 = pd.read_csv('../data/GLRMk5.csv')
df_pat = pd.read_csv('../data/Diabetes_Numerical.csv')

# %% [markdown]
# ## Function for regression training

# %%
def train_LR(X_train, X_test, y_train, y_test, i):
    # create training and testing vars
    #X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
    print(X_train.shape, y_train.shape)
    print(X_test.shape, y_test.shape)
    lm = LinearRegression()
    model = lm.fit(X_train, y_train)
    y_pred = lm.predict(X_test)
    print("Score:", MSE(y_pred, y_test), '\n')
    #print(confusion_matrix(y_test, y_pred))
    #print(classification_report(y_test, y_pred))

# %%
def train_DT(X_train, X_test, y_train, y_test, i):
    # create training and testing vars
    print(X_train.shape, y_train.shape)
    print(X_test.shape, y_test.shape)
    dt = DecisionTreeRegressor()
    model = dt.fit(X_train, y_train)
    y_pred = dt.predict(X_test)
    print("Score:", MSE(y_pred, y_test), '\n')
    #print(confusion_matrix(y_test, y_pred))
    #print(classification_report(y_test, y_pred))

# %%
def trainModel(df_clus, df_pat, size):
    df_clus = df_clus.transpose()
    
    # get the clusters
    clusters = []
    for i in range(size):
        this_cluster = df_clus[df_clus[i] == 1]
        clusters.append(this_cluster)
    
    # get the index
    cluster = []
    for i in range(size):
        this_cluster = list(map(lambda x: int(x[1:]) - 1, list(clusters[i].index)))
        cluster.append(this_cluster)
        
    # split the patient dataframe
    pat_clustered = []
    for i in range(size):
        this_clu = df_pat[df_pat.index.isin(cluster[i])]
        pat_clustered.append(this_clu)
    for i in range(size):
        this_c = pat_clustered[i]
        if (len(this_c) > 0):
            this_df = this_c.iloc[:, 2:]
            y = this_df.LOS
            X = this_df.iloc[:, 1:]
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
            print('\n Cluster '+ str(i+1)+ ': \n')
            print('Linear Regression: ')
            train_LR(X_train, X_test, y_train, y_test, i)
            print('Decission Tree: ')
            train_DT(X_train, X_test, y_train, y_test, i)
        else:
            print('Cluster'+ str(i+1)+ ' is empty. \n')

# %% [markdown]
# ## Model Output

# %%
trainModel(hinge20, df_pat, 20)
# Out:
#  Cluster 1:
#
# Linear Regression:
# (375, 919) (375,)
# (126, 919) (126,)
# Score: 276.74341405021306
#
# Decission Tree:
# (375, 919) (375,)
# (126, 919) (126,)
# Score: 222.17082162214285
#
#
#  Cluster 2:
#
# Linear Regression:
# (379, 919) (379,)
# (127, 919) (127,)
# Score: 2.2263481992665875e+21
#
# Decission Tree:
# (379, 919) (379,)
# (127, 919) (127,)
# Score: 99.77521335716533
#
#
#  Cluster 3:
#
# Linear Regression:
# (381, 919) (381,)
# (128, 919) (128,)
# Score: 5464.893237634436
#
# Decission Tree:
# (381, 919) (381,)
# (128, 919) (128,)
# Score: 104.67792638242189
#
#
#  Cluster 4:
#
# Linear Regression:
# (352, 919) (352,)
# (118, 919) (118,)
# Score: 390.25985145533474
#
# Decission Tree:
# (352, 919) (352,)
# (118, 919) (118,)
# Score: 165.5884448788135
#
#
#  Cluster 5:
#
# Linear Regression:
# (400, 919) (400,)
# (134, 919) (134,)
# Score: 86140.45181483444
#
# Decission Tree:
# (400, 919) (400,)
# (134, 919) (134,)
# Score: 221.8245692963433
#
#
#  Cluster 6:
#
# Linear Regression:
# (397, 919) (397,)
# (133, 919) (133,)
# Score: 22382.442880599472
#
# Decission Tree:
# (397, 919) (397,)
# (133, 919) (133,)
# Score: 269.58194823932337
#
#
#  Cluster 7:
#
# Linear Regression:
# (360, 919) (360,)
# (121, 919) (121,)
# Score: 491.41252731902483
#
# Decission Tree:
# (360, 919) (360,)
# (121, 919) (121,)
# Score: 70.32624048876032
#
#
#  Cluster 8:
#
# Linear Regression:
# (360, 919) (360,)
# (120, 919) (120,)
# Score: 536.2597882283409
#
# Decission Tree:
# (360, 919) (360,)
# (120, 919) (120,)
# Score: 73.73428423033333
#
#
#  Cluster 9:
#
# Linear Regression:
# (330, 919) (330,)
# (110, 919) (110,)
# Score: 199.54177618451268
#
# Decission Tree:
# (330, 919) (330,)
# (110, 919) (110,)
# Score: 133.63225075318186
#
#
#  Cluster 10:
#
# Linear Regression:
# (411, 919) (411,)
# (138, 919) (138,)
# Score: 1571.650491638534
#
# Decission Tree:
# (411, 919) (411,)
# (138, 919) (138,)
# Score: 183.26630420557973
#
#
#  Cluster 11:
#
# Linear Regression:
# (423, 919) (423,)
# (142, 919) (142,)
# Score: 7.459685642137967e+20
#
# Decission Tree:
# (423, 919) (423,)
# (142, 919) (142,)
# Score: 131.10319643241192
#
#
#  Cluster 12:
#
# Linear Regression:
# (400, 919) (400,)
# (134, 919) (134,)
# Score: 57321.644488325524
#
# Decission Tree:
# (400, 919) (400,)
# (134, 919) (134,)
# Score: 118.71866053470148
#
#
#  Cluster 13:
#
# Linear Regression:
# (405, 919) (405,)
# (135, 919) (135,)
# Score: 1.1657912310574567e+25
#
# Decission Tree:
# (405, 919) (405,)
# (135, 919) (135,)
# Score: 385.0038254307408
#
#
#  Cluster 14:
#
# Linear Regression:
# (399, 919) (399,)
# (134, 919) (134,)
# Score: 7.318780625713516e+20
#
# Decission Tree:
# (399, 919) (399,)
# (134, 919) (134,)
# Score: 142.0647232041045
#
#
#  Cluster 15:
#
# Linear Regression:
# (404, 919) (404,)
# (135, 919) (135,)
# Score: 118010.77971495371
#
# Decission Tree:
# (404, 919) (404,)
# (135, 919) (135,)
# Score: 150.68121440370373
#
#
#  Cluster 16:
#
# Linear Regression:
# (336, 919) (336,)
# (112, 919) (112,)
# Score: 469.43741612840716
#
# Decission Tree:
# (336, 919) (336,)
# (112, 919) (112,)
# Score: 93.40417258571428
#
#
#  Cluster 17:
#
# Linear Regression:
# (402, 919) (402,)
# (134, 919) (134,)
# Score: 140226.8887923759
#
# Decission Tree:
# (402, 919) (402,)
# (134, 919) (134,)
# Score: 53.132341541791064
#
#
#  Cluster 18:
#
# Linear Regression:
# (420, 919) (420,)
# (141, 919) (141,)
# Score: 1.3651168282557373e+21
#
# Decission Tree:
# (420, 919) (420,)
# (141, 919) (141,)
# Score: 122.3084444669149
#
#
#  Cluster 19:
#
# Linear Regression:
# (415, 919) (415,)
# (139, 919) (139,)
# Score: 1551.3713146564282
#
# Decission Tree:
# (415, 919) (415,)
# (139, 919) (139,)
# Score: 97.48669187964029
#
#
#  Cluster 20:
#
# Linear Regression:
# (375, 919) (375,)
# (125, 919) (125,)
# Score: 4552.0870994540255
#
# Decission Tree:
# (375, 919) (375,)
# (125, 919) (125,)
# Score: 63.330688338320016

# %%
trainModel(hinge10, df_pat, 10)
# Out:
#  Cluster 1:
#
# Linear Regression:
# (728, 919) (728,)
# (243, 919) (243,)
# Score: 2.168288898802018e+24
#
# Decission Tree:
# (728, 919) (728,)
# (243, 919) (243,)
# Score: 114.42188817209876
#
#
#  Cluster 2:
#
# Linear Regression:
# (756, 919) (756,)
# (252, 919) (252,)
# Score: 1.677608368994844e+23
#
# Decission Tree:
# (756, 919) (756,)
# (252, 919) (252,)
# Score: 108.53899562829363
#
#
#  Cluster 3:
#
# Linear Regression:
# (725, 919) (725,)
# (242, 919) (242,)
# Score: 4.70062871461922e+19
#
# Decission Tree:
# (725, 919) (725,)
# (242, 919) (242,)
# Score: 88.0000595883058
#
#
#  Cluster 4:
#
# Linear Regression:
# (785, 919) (785,)
# (262, 919) (262,)
# Score: 1.7815212141614795e+21
#
# Decission Tree:
# (785, 919) (785,)
# (262, 919) (262,)
# Score: 108.9387334041603
#
#
#  Cluster 5:
#
# Linear Regression:
# (769, 919) (769,)
# (257, 919) (257,)
# Score: 6.321669994171994e+21
#
# Decission Tree:
# (769, 919) (769,)
# (257, 919) (257,)
# Score: 180.95054978392994
#
#
#  Cluster 6:
#
# Linear Regression:
# (739, 919) (739,)
# (247, 919) (247,)
# Score: 1.1232477462868231e+22
#
# Decission Tree:
# (739, 919) (739,)
# (247, 919) (247,)
# Score: 174.43599453287447
#
#
#  Cluster 7:
#
# Linear Regression:
# (852, 919) (852,)
# (285, 919) (285,)
# Score: 1.8326014123314305e+23
#
# Decission Tree:
# (852, 919) (852,)
# (285, 919) (285,)
# Score: 85.70008317838597
#
#
#  Cluster 8:
#
# Linear Regression:
# (795, 919) (795,)
# (266, 919) (266,)
# Score: 1.083336532424258e+25
#
# Decission Tree:
# (795, 919) (795,)
# (266, 919) (266,)
# Score: 99.37038327814851
#
#
#  Cluster 9:
#
# Linear Regression:
# (787, 919) (787,)
# (263, 919) (263,)
# Score: 1.69624636884906e+23
#
# Decission Tree:
# (787, 919) (787,)
# (263, 919) (263,)
# Score: 112.88407463593154
#
#
#  Cluster 10:
#
# Linear Regression:
# (792, 919) (792,)
# (265, 919) (265,)
# Score: 4.082786945455096e+22
#
# Decission Tree:
# (792, 919) (792,)
# (265, 919) (265,)
# Score: 109.3986968718868

# %%
trainModel(origin20, df_pat, 20)
# Out:
#  Cluster 1:
#
# Linear Regression:
# (2, 919) (2,)
# (1, 919) (1,)
# Score: 0.9728305730812852
#
# Decission Tree:
# (2, 919) (2,)
# (1, 919) (1,)
# Score: 1.3064489999999995
#
#
#  Cluster 2:
#
# Linear Regression:
# (844, 919) (844,)
# (282, 919) (282,)
# Score: 2.4838054646228114e+20
#
# Decission Tree:
# (844, 919) (844,)
# (282, 919) (282,)
# Score: 7.294645110469859
#
#
#  Cluster 3:
#
# Linear Regression:
# (2, 919) (2,)
# (1, 919) (1,)
# Score: 76.62680296963991
#
# Decission Tree:
# (2, 919) (2,)
# (1, 919) (1,)
# Score: 137.82759999999996
#
#
#  Cluster 4:
#
# Linear Regression:
# (1214, 919) (1214,)
# (405, 919) (405,)
# Score: 3.1848808659317703e+24
#
# Decission Tree:
# (1214, 919) (1214,)
# (405, 919) (405,)
# Score: 319.09315101126543
#
#
#  Cluster 5:
#
# Linear Regression:
# (76, 919) (76,)
# (26, 919) (26,)
# Score: 178.1899646812685
#
# Decission Tree:
# (76, 919) (76,)
# (26, 919) (26,)
# Score: 256.36059411153843
#
#
#  Cluster 6:
#
# Linear Regression:
# (75, 919) (75,)
# (26, 919) (26,)
# Score: 26.385646072334534
#
# Decission Tree:
# (75, 919) (75,)
# (26, 919) (26,)
# Score: 40.03487453038462
#
# Cluster7is empty.
#
#
#  Cluster 8:
#
# Linear Regression:
# (26, 919) (26,)
# (9, 919) (9,)
# Score: 1.0259906485115065
#
# Decission Tree:
# (26, 919) (26,)
# (9, 919) (9,)
# Score: 0.933721671111111
#
#
#  Cluster 9:
#
# Linear Regression:
# (1749, 919) (1749,)
# (584, 919) (584,)
# Score: 6.88356747700134e+20
#
# Decission Tree:
# (1749, 919) (1749,)
# (584, 919) (584,)
# Score: 74.43274424096319
#
#
#  Cluster 10:
#
# Linear Regression:
# (3, 919) (3,)
# (2, 919) (2,)
# Score: 140.61294775157916
#
# Decission Tree:
# (3, 919) (3,)
# (2, 919) (2,)
# Score: 104.09558393
#
#
#  Cluster 11:
#
# Linear Regression:
# (378, 919) (378,)
# (126, 919) (126,)
# Score: 8.189104682937275e+18
#
# Decission Tree:
# (378, 919) (378,)
# (126, 919) (126,)
# Score: 16.975734897619045
#
#
#  Cluster 12:
#
# Linear Regression:
# (1068, 919) (1068,)
# (357, 919) (357,)
# Score: 7.826583601651541e+21
#
# Decission Tree:
# (1068, 919) (1068,)
# (357, 919) (357,)
# Score: 10.340966129985995
#
#
#  Cluster 13:
#
# Linear Regression:
# (3, 919) (3,)
# (2, 919) (2,)
# Score: 6.875200591805711
#
# Decission Tree:
# (3, 919) (3,)
# (2, 919) (2,)
# Score: 12.285313404999998
#
#
#  Cluster 14:
#
# Linear Regression:
# (1644, 919) (1644,)
# (548, 919) (548,)
# Score: 7.546102722195047e+20
#
# Decission Tree:
# (1644, 919) (1644,)
# (548, 919) (548,)
# Score: 13.356585136610402
#
#
#  Cluster 15:
#
# Linear Regression:
# (15, 919) (15,)
# (5, 919) (5,)
# Score: 41.781758037321914
#
# Decission Tree:
# (15, 919) (15,)
# (5, 919) (5,)
# Score: 19.088812425999997
#
#
#  Cluster 16:
#
# Linear Regression:
# (55, 919) (55,)
# (19, 919) (19,)
# Score: 0.5078997729116483
#
# Decission Tree:
# (55, 919) (55,)
# (19, 919) (19,)
# Score: 0.8756946721052633
#
#
#  Cluster 17:
#
# Linear Regression:
# (260, 919) (260,)
# (87, 919) (87,)
# Score: 701259923874.3667
#
# Decission Tree:
# (260, 919) (260,)
# (87, 919) (87,)
# Score: 4.281503497011494
#
# Cluster18is empty.
#
#
#  Cluster 19:
#
# Linear Regression:
# (312, 919) (312,)
# (104, 919) (104,)
# Score: 354.2728449041514
#
# Decission Tree:
# (312, 919) (312,)
# (104, 919) (104,)
# Score: 5.721591894903847
#
# Cluster20is empty.

# %%
trainModel(origin5, df_pat, 5)
# Out:
#  Cluster 1:
#
# Linear Regression:
# (1305, 919) (1305,)
# (435, 919) (435,)
# Score: 3.11717787141021e+21
#
# Decission Tree:
# (1305, 919) (1305,)
# (435, 919) (435,)
# Score: 46.637861079505754
#
#
#  Cluster 2:
#
# Linear Regression:
# (1336, 919) (1336,)
# (446, 919) (446,)
# Score: 5.005497871319418e+23
#
# Decission Tree:
# (1336, 919) (1336,)
# (446, 919) (446,)
# Score: 59.074850798139025
#
#
#  Cluster 3:
#
# Linear Regression:
# (1627, 919) (1627,)
# (543, 919) (543,)
# Score: 4.856969579464074e+21
#
# Decission Tree:
# (1627, 919) (1627,)
# (543, 919) (543,)
# Score: 60.81166929189687
#
#
#  Cluster 4:
#
# Linear Regression:
# (1708, 919) (1708,)
# (570, 919) (570,)
# Score: 9.3250837966453e+21
#
# Decission Tree:
# (1708, 919) (1708,)
# (570, 919) (570,)
# Score: 143.6794446899561
#
#
#  Cluster 5:
#
# Linear Regression:
# (1755, 919) (1755,)
# (585, 919) (585,)
# Score: 6.348875613464738e+21
#
# Decission Tree:
# (1755, 919) (1755,)
# (585, 919) (585,)
# Score: 140.23389820241033
